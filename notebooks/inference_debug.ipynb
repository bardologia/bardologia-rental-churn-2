# %% [markdown]
# # Debug de Inferência (step-by-step)
# Notebook para validar visualmente a classe de inferência usando `data/inference.parquet` com 3 usuários.

# %% [markdown]
# ## 1) Carregar dependências e configurar ambiente
# Importe bibliotecas e ajuste o caminho do projeto.

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import torch

project_root = Path.cwd().parents[0]
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from main.config import config
from core.model import Model
from core.inference import InferenceEngine

# %% [markdown]
# ## 2) Ler `inference.parquet` em um DataFrame
# Carregue o arquivo e inspecione o schema.

# %%
import pyarrow.parquet as pq

data_path = project_root / "data" / "inference.parquet"
assert data_path.exists(), f"Arquivo não encontrado: {data_path}"

# Ler com pyarrow ignorando metadata pandas
table = pq.read_table(data_path)

# Converter para pandas sem usar metadata
df_raw = table.to_pandas(ignore_metadata=True, strings_to_categorical=False)

# Converter colunas Decimal para float
for col in df_raw.select_dtypes(include=['object']).columns:
    try:
        df_raw[col] = pd.to_numeric(df_raw[col], errors='ignore')
    except:
        pass

print(df_raw.shape)
df_raw.head(5)
# Out:
# (345, 99)
# C:\Users\Victo\AppData\Local\Temp\ipykernel_23976\1257440772.py:15: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_raw[col] = pd.to_numeric(df_raw[col], errors='ignore')
#    usuarioId  locacaoId  locacaoCicloId  situacao_locacao  parcelaId  \
# 0    4976086    5353690          496288                60   89452538
# 1    2013977    2177516          220167                60   69483755
# 2    2013977    2177516          220167                60   69483751
# 3    4976086    5353690          496288                60   89452531
# 4    4976086    5353690          496288                60   89452518
#
#            parcelaTipo  parcelaTipoId  usuarioMovimentoCaucaoId  \
# 0  Aluguel Minha Sport              7                         0
# 1              Aluguel              3                         0
# 2              Aluguel              3                         0
# 3  Aluguel Minha Sport              7                         0
# 4  Aluguel Minha Sport              7                         0
#
#    veiculoEventoMultaId codigoMulta  ...  regiaoId  paisId  pacoteId  \
# 0                   0.0           -  ...         2       1      4004
# 1                   0.0           -  ...         2       1      2026
# 2                   0.0           -  ...         2       1      2026
# 3                   0.0           -  ...         2       1      4004
# 4                   0.0           -  ...         2       1      4004
#
#                 pacoteNome pacoteTipoId recorrencia_pagamento  \
# 0  Conquiste Sport ESD 0km            6                mensal
# 1  Sport - Minha Mottu 0Km            2               semanal
# 2  Sport - Minha Mottu 0Km            2               semanal
# 3  Conquiste Sport ESD 0km            6                mensal
# 4  Conquiste Sport ESD 0km            6                mensal
#
#    pacoteDuracaoTipoId pacoteDuracao          moeda  \
# 0                    2            36  Real - Brasil
# 1                    1           728  Real - Brasil
# 2                    1           728  Real - Brasil
# 3                    2            36  Real - Brasil
# 4                    2            36  Real - Brasil
#
#                     atualizacao_dt
# 0 2026-01-28 13:47:58.931300+00:00
# 1 2026-01-28 13:47:58.931300+00:00
# 2 2026-01-28 13:47:58.931300+00:00
# 3 2026-01-28 13:47:58.931300+00:00
# 4 2026-01-28 13:47:58.931300+00:00
#
# [5 rows x 99 columns]

# %%
df_raw.dtypes
# Out:
# usuarioId                              int64
# locacaoId                              int64
# locacaoCicloId                         int64
# situacao_locacao                       int64
# parcelaId                              int64
#                                 ...
# recorrencia_pagamento                 object
# pacoteDuracaoTipoId                    int64
# pacoteDuracao                          int64
# moeda                                 object
# atualizacao_dt           datetime64[us, UTC]
# Length: 99, dtype: object

# %% [markdown]
# ## 3) Exibir amostra dos 3 usuários para validação visual
# Mostre alguns campos-chave por usuário.

# %%
user_col = config.columns.user_id_col
creation_col = config.columns.creation_date_col
payment_col = config.columns.payment_date_col
delay_col = config.columns.delay_col

users = df_raw[user_col].dropna().unique().tolist()
print("Usuarios:", users)

cols_preview = [user_col, creation_col, config.columns.due_date_col, payment_col, delay_col]
cols_preview = [c for c in cols_preview if c in df_raw.columns]

(df_raw
 .sort_values([user_col, creation_col])
 .loc[:, cols_preview]
 .groupby(user_col)
 .head(10)
)
# Out:
# Usuarios: [4976086, 2013977, 1000667]
#      usuarioId                      criacaoData vencimentoData  \
# 29     1000667 2023-06-26 18:38:05.637000+00:00     2023-06-27
# 30     1000667 2023-06-26 18:38:05.637000+00:00     2023-06-27
# 31     1000667 2023-06-26 18:38:05.637000+00:00     2023-06-27
# 5      1000667 2023-06-27 16:53:51.277000+00:00     2023-09-07
# 21     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-31
# 23     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-17
# 24     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-17
# 49     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-24
# 58     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-10
# 59     1000667 2023-06-27 16:53:51.277000+00:00     2023-08-10
# 41     2013977 2024-08-05 19:42:51.660000+00:00     2024-10-14
# 42     2013977 2024-08-05 19:42:51.660000+00:00     2024-10-14
# 43     2013977 2024-08-05 19:42:51.660000+00:00     2024-10-14
# 50     2013977 2024-08-05 19:42:51.660000+00:00     2024-10-07
# 51     2013977 2024-08-05 19:42:51.660000+00:00     2024-10-07
# 75     2013977 2024-08-05 19:42:51.660000+00:00     2024-09-16
# 96     2013977 2024-08-05 19:42:51.660000+00:00     2024-08-12
# 163    2013977 2024-08-05 19:42:51.660000+00:00     2024-08-19
# 173    2013977 2024-08-05 19:42:51.660000+00:00     2024-09-09
# 174    2013977 2024-08-05 19:42:51.660000+00:00     2024-09-09
# 9      4976086 2025-12-09 16:21:20.700000+00:00     2026-05-05
# 14     4976086 2025-12-09 16:21:20.700000+00:00     2026-03-05
# 25     4976086 2025-12-09 16:21:20.700000+00:00     2026-07-05
# 45     4976086 2025-12-09 16:21:20.700000+00:00     2026-08-05
# 54     4976086 2025-12-09 16:21:20.700000+00:00     2026-10-05
# 77     4976086 2025-12-09 16:21:20.700000+00:00     2026-06-05
# 169    4976086 2025-12-09 16:21:20.700000+00:00     2026-04-05
# 192    4976086 2025-12-09 16:21:20.700000+00:00     2026-02-05
# 231    4976086 2025-12-09 16:21:20.700000+00:00     2026-09-05
# 250    4976086 2025-12-09 16:21:20.700000+00:00     2026-01-05
#
#                 pagamentoData  Dias_atraso
# 29  2023-06-26 18:43:50+00:00         -1.0
# 30  2023-06-26 18:43:50+00:00         -1.0
# 31  2023-06-26 18:43:50+00:00         -1.0
# 5   2023-09-07 22:42:03+00:00          0.0
# 21  2023-08-31 20:22:53+00:00          0.0
# 23  2023-08-18 17:34:07+00:00          1.0
# 24  2023-08-18 17:34:07+00:00          1.0
# 49  2023-08-24 22:49:01+00:00          0.0
# 58  2023-08-11 00:12:03+00:00          1.0
# 59  2023-08-11 00:12:03+00:00          1.0
# 41  2024-10-14 19:53:39+00:00          0.0
# 42  2024-10-14 19:53:39+00:00          0.0
# 43  2024-10-14 19:53:39+00:00          0.0
# 50  2024-10-07 20:01:25+00:00          0.0
# 51  2024-10-07 20:01:25+00:00          0.0
# 75  2024-09-16 22:55:17+00:00          0.0
# 96  2024-08-11 19:50:43+00:00         -1.0
# 163 2024-08-18 22:04:35+00:00         -1.0
# 173 2024-09-09 22:43:27+00:00          0.0
# 174 2024-09-09 22:43:27+00:00          0.0
# 9                         NaT          NaN
# 14                        NaT          NaN
# 25                        NaT          NaN
# 45                        NaT          NaN
# 54                        NaT          NaN
# 77                        NaT          NaN
# 169                       NaT          NaN
# 192                       NaT          NaN
# 231                       NaT          NaN
# 250 2025-12-20 20:10:09+00:00         -1.0

# %% [markdown]
# ## 4) Instanciar a classe e executar passo a passo
# Carregar metadata/estado do modelo, preparar dados e montar sequências.

# %%
runs_dir = project_root / config.paths.runs_dir
meta_files = sorted(runs_dir.glob("**/model_metadata.pt"), key=lambda p: p.stat().st_mtime, reverse=True)
assert meta_files, "Nenhum model_metadata.pt encontrado em runs/"

metadata_path = meta_files[0]
run_dir = metadata_path.parent
state_dict_path = run_dir / "model_state_dict.pt"

metadata = torch.load(metadata_path, map_location="cpu", weights_only=False)

model = Model(
    embedding_dimensions=metadata["embedding_dimensions"],
    num_continuous=metadata["num_continuous"],
    target_scaler=metadata.get("target_scaler"),
    feature_scaler=metadata.get("feature_scaler"),
    config=metadata["config"],
)

if state_dict_path.exists():
    model.load_state_dict(torch.load(state_dict_path, map_location="cpu"))
else:
    print("Aviso: model_state_dict.pt não encontrado. Usando pesos atuais do modelo recém-criado.")

engine = InferenceEngine(
    model=model,
    target_scaler=metadata.get("target_scaler"),
    feature_scalers=metadata.get("feature_scaler"),
    config=metadata["config"],
    categorical_maps=metadata.get("categorical_maps", {}),
)

prepared = engine._prepare_dataframe(df_raw)
sequences, meta_rows = engine._build_sequences(prepared)

len(sequences), [len(s) for s in sequences]
# Out:
# [22:44:48] [Temporal Features] Extracted 13 features
#
# [22:44:48] [History Features] Extracted 5 features
#
# [22:44:48] [Sequence Features] Extracted 12 features
#
# [22:44:48] [Value Features] Extracted 5 features
# c:\Users\Victo\OneDrive\Área de Trabalho\rental-churn - 2\rental-churn\core\data.py:104: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply
# 38  2024-11-05 09:16:30+00:00          1.0
# 37  2024-10-28 17:10:25+00:00          0.0
# 36  2024-10-21 19:57:37+00:00          0.0
# 45  2024-12-25 12:40:51+00:00          0.0
# 81  2025-09-03 19:36:34+00:00          0.0
# 57  2025-03-19 09:58:35+00:00          0.0
# 59  2025-04-02 23:40:28+00:00          0.0
# 79  2025-08-20 18:37:55+00:00          0.0
# 78  2025-08-13 22:45:33+00:00          0.0
# 77  2025-08-06 21:31:00+00:00          0.0
# 75  2025-07-23 23:39:23+00:00          0.0
# 74  2025-07-16 18:33:35+00:00          0.0
# 73  2025-07-09 18:39:29+00:00          0.0
# 72  2025-06-30 16:18:19+00:00         -1.0
# 71  2025-06-25 16:11:11+00:00          0.0
# 58  2025-03-26 23:22:49+00:00          0.0
# 70  2025-06-17 12:51:09+00:00         -1.0
# 68  2025-06-04 12:27:06+00:00          0.0
# 67  2025-05-28 16:33:11+00:00          0.0
# 66  2025-05-21 23:52:26+00:00          0.0
# 65  2025-05-14 17:39:43+00:00          0.0
# 64  2025-05-08 23:20:22+00:00          1.0
# 63  2025-04-30 23:27:58+00:00          0.0
# 62  2025-04-22 21:40:52+00:00         -1.0
# 61  2025-04-16 22:05:33+00:00          0.0
# 60  2025-04-08 17:22:14+00:00         -1.0
# 69  2025-06-12 07:01:45+00:00          1.0
# 103                       NaT          NaN
#      usuarioId                      criacaoData            vencimentoData  \
# 129    4976086 2025-12-09 16:21:20.700000+00:00 2025-12-09 00:00:00+00:00
# 130    4976086 2025-12-09 16:21:20.700000+00:00 2026-01-05 00:00:00+00:00
# 131    4976086 2025-12-09 16:21:20.700000+00:00 2026-02-05 00:00:00+00:00
#
#                 pagamentoData  Dias_atraso
# 129 2025-12-09 16:21:56+00:00          0.0
# 130 2025-12-20 20:10:09+00:00         -1.0
# 131                       NaT          NaN

# %%
preds_df = engine.predict(df_raw)
preds_df
# Out:
# [22:44:49] [Temporal Features] Extracted 13 features
#
# [22:44:49] [History Features] Extracted 5 features
#
# [22:44:49] [Sequence Features] Extracted 12 features
#
# [22:44:49] [Value Features] Extracted 5 features
# c:\Users\Victo\OneDrive\Área de Trabalho\rental-churn - 2\rental-churn\core\data.py:104: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(process_user_history)
#    usuarioId  locacaoId  ordem_parcela                      criacaoData  \
# 0    2013977    2177516             26 2024-08-06 12:33:36.533000+00:00
# 1    4976086    5353690             36 2025-12-09 16:21:20.700000+00:00
#
#              vencimentoData pagamentoData  predicted_days_to_payment  \
# 0 2026-02-04 00:00:00+00:00           NaT                   6.751598
# 1 2026-02-05 00:00:00+00:00           NaT                   0.000000
#
#    sequence_length
# 0               50
# 1                3

# %% [markdown]
# ## 6) Salvar/Exportar resultados para conferência
# Salve os resultados finais para inspeção externa.

# %%
output_path = project_root / "data" / "inference_results.csv"
preds_df.to_csv(output_path, index=False)
print("Salvo em:", output_path)
# Out:
# Salvo em: c:\Users\Victo\OneDrive\Área de Trabalho\rental-churn - 2\rental-churn\data\inference_results.csv
